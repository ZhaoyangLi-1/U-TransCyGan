# %%
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
from torch.nn.functional import conv2d
import torch

# %%
def show_loss_graph(epoch_array, loss_Array, file_pth, title):
    plt.figure(figsize=(12,8))
    plt.plot(epoch_array, loss_Array, marker='o', label='D_loss', color='r')
    plt.xlabel("Epoch")
    plt.xlabel("Loss")
    plt.title(title)
    plt.legend()
    plt.savefig(file_pth)
    plt.show

# %%
epoch_array = np.array(range(1, 1000+1))
D_loss_mri_array = np.array(range(1, 1000+1))
D_loss_pet_array = np.array(range(1, 1000+1))
G_loss_array = np.array(range(1, 1000+1))

# %%
show_loss_graph(epoch_array, G_loss_array, "./Generator_loss.jpg", "Generator Loss")
show_loss_graph(epoch_array, D_loss_mri_array, "./Disc_mri_loss.jpg", "Discriminator MRI Loss")
show_loss_graph(epoch_array, D_loss_pet_array, "./Disc_pet_loss.jpg", "Discriminator PET Loss")

# %%
a = np.array([[1,2]])
print(a[0][1])
print(a[0][0])

print("The Equation is y = [{}, {}]*X+{}".format(a[0][0], a[0][1], 2))
# Out:
# 2
# 1
# The Equation is y = [1, 2]*X+2

# %%
M = torch.tensor([[2, 5, 1, 4], [3, 2, 4, 3], [5, 4, 2, 2], [1, 2, 4, 5]])
#print(M)
Mx = torch.tensor([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
#print(Mx)
print(conv2d(M, Mx, padding=0))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_3580284/1581165266.py in <module>
#       3 Mx = torch.tensor([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
#       4 #print(Mx)
# ----> 5 print(conv2d(M, Mx, padding=0))
#
# RuntimeError: Expected 3D (unbatched) or 4D (batched) input to conv2d, but got input of size: [4, 4]
